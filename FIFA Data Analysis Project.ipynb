# %%
#Data analysis
import numpy as np
import pandas as pd

#Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.simplefilter(action='ignore',category=Warning)

pd.set_option('display.max_columns',None)
fifa=pd.read_csv('players_22.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age         dob  height_cm  \
# ...

# %%
fifa.shape
# Out:
# (19239, 110)

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19239 entries, 0 to 19238
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(16), int64(44), object(50)
# memory usage: 16.1+ MB

# %% [markdown]
# **Dropping Columns From Analysis**

# %%
fifa.drop(['player_url','long_name','club_jersey_number','club_loaned_from','nation_jersey_number','player_face_url','club_flag_url','club_logo_url','nation_logo_url','nation_flag_url'],axis=1,inplace=True)

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19239 entries, 0 to 19238
# Data columns (total 100 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   sofifa_id                    19239 non-null  int64
#  1   short_name                   19239 non-null  object
#  2   player_positions             19239 non-null  object
#  3   overall                      19239 non-null  int64
#  4   potential                    19239 non-null  int64
#  5   value_eur                    19165 non-null  float64
#  6   wage_eur                     19178 non-null  float64
#  7   age                          19239 non-null  int64
#  8   dob                          19239 non-null  object
#  9   height_cm                    19239 non-null  int64
#  10  weight_kg                    19239 non-null  int64
#  11  club_team_id                 19178 non-null  float64
#  12  club_name                    19178 non-null  object
# ...

# %% [markdown]
# **Data Cleaning**

# %%
#Numerical Features
fifa['international_reputation'].fillna(fifa['international_reputation'].mean(),inplace=True)
fifa['skill_moves'].fillna(fifa['skill_moves'].mean(),inplace=True)
fifa['weak_foot'].fillna(fifa['weak_foot'].mean(),inplace=True)
fifa['passing'].fillna(fifa['passing'].mean(),inplace=True)

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19239 entries, 0 to 19238
# Data columns (total 100 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   sofifa_id                    19239 non-null  int64
#  1   short_name                   19239 non-null  object
#  2   player_positions             19239 non-null  object
#  3   overall                      19239 non-null  int64
#  4   potential                    19239 non-null  int64
#  5   value_eur                    19165 non-null  float64
#  6   wage_eur                     19178 non-null  float64
#  7   age                          19239 non-null  int64
#  8   dob                          19239 non-null  object
#  9   height_cm                    19239 non-null  int64
#  10  weight_kg                    19239 non-null  int64
#  11  club_team_id                 19178 non-null  float64
#  12  club_name                    19178 non-null  object
# ...
